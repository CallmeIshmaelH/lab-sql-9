# %% [markdown]
# # Lab | SQL Queries 9
#
# In this lab, you will be using the [Sakila](https://dev.mysql.com/doc/sakila/en/) database of movie rentals. You have been using this database for a couple labs already, but if you need to get the data again, refer to the official [installation link](https://dev.mysql.com/doc/sakila/en/sakila-installation.html).
#
# The database is structured as follows:
# ![DB schema](https://education-team-2020.s3-eu-west-1.amazonaws.com/data-analytics/database-sakila-schema.png)
#
# ### Instructions
#
# Create a Python connection with SQL database and retrieve the results of the following queries as dataframes:
#
# 1. How many distinct (different) actors' last names are there?
# 2. Add an additional column day_type with values 'weekend' and 'workday' depending on the rental day of the week.
# 3. Get all films with ARMAGEDDON in the title.
# 4. Get 10 the longest films.
# 5. How many films include Behind the Scenes content?
# 6.  Which kind of movies (rating) have a mean duration of more than two hours?
# 7.  Rank films by length (filter out the rows that have nulls or 0s in length column). In your output, only select the columns title, length, and the rank.

# %%
# import libraries
import pandas as pd
import numpy as np
import getpass
import sklearn 
import pymysql
from sqlalchemy import create_engine

# %%
# create password object
password = getpass.getpass('Input MySQL Password:')

# %%
# create connection string
connect_string = 'mysql+pymysql://root:' + password + '@localhost/sakila'
# create engine object
engine_sakila = create_engine(connect_string)

# %% [markdown]
# 1. How many distinct (different) actors' last names are there?
# 2. Add an additional column day_type with values 'weekend' and 'workday' depending on the rental day of the week.
# 3. Get all films with ARMAGEDDON in the title.
# 4. Get 10 the longest films.
# 5. How many films include Behind the Scenes content?
# 6.  Which kind of movies (rating) have a mean duration of more than two hours?
# 7.  Rank films by length (filter out the rows that have nulls or 0s in length column). In your output, only select the columns title, length, and the rank.

# %%
# find count of distinct actor' last names.
actor_query = "SELECT count(distinct(last_name)) as 'Distinct Last Names(count)' from sakila.actor;"
actor_lname= pd.read_sql_query(actor_query, engine_sakila)
actor_lname.head()
# Out:
#    Distinct Last Names(count)
# 0                         121

# %%
# Add an additional column day_type with values 'weekend' and 'workday' depending on the rental day of the week.
rental_query = "SELECT *, CASE WHEN DAYNAME(rental_date) IN ('Saturday', 'Sunday') THEN 'Weekend' ELSE 'Weekday' END AS 'Day_Type' FROM sakila.rental;"
rental_week_status = pd.read_sql_query(rental_query, engine_sakila)
rental_week_status.head()
# Out:
#    rental_id         rental_date  inventory_id  customer_id  \
# 0          1 2005-05-24 22:53:30           367          130
# 1          2 2005-05-24 22:54:33          1525          459
# 2          3 2005-05-24 23:03:39          1711          408
# 3          4 2005-05-24 23:04:41          2452          333
# 4          5 2005-05-24 23:05:21          2079          222
#
#           return_date  staff_id         last_update Day_Type
# 0 2005-05-26 22:04:30         1 2006-02-15 21:30:53  Weekday
# 1 2005-05-28 19:40:33         1 2006-02-15 21:30:53  Weekday
# 2 2005-06-01 22:12:39         1 2006-02-15 21:30:53  Weekday
# 3 2005-06-03 01:43:41         2 2006-02-15 21:30:53  Weekday
# 4 2005-06-02 04:33:21         1 2006-02-15 21:30:53  Weekday

# %%
# Get all films with ARMAGEDDON in the title.
ARMAGEDDON_query = "SELECT * FROM sakila.film WHERE film.title LIKE '%ARMAGEDDON%';"
ARMAGEDDONs = pd.read_sql_query(ARMAGEDDON_query, engine_sakila)
ARMAGEDDONs.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34016/3035665765.py in <module>
#       1 # Get all films with ARMAGEDDON in the title.
#       2 ARMAGEDDON_query = "select * from sakila.film where title like '%ARMAGEDDON%';"
# ----> 3 ARMAGEDDONs = pd.read_sql_query(ARMAGEDDON_query, engine_sakila)
#       4 ARMAGEDDONs.head()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     434     """
#     435     pandas_sql = pandasSQL_builder(con)
# --> 436     return pandas_sql.read_query(
#     437         sql,
#     438         index_col=index_col,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1577         args = _convert_params(sql, params)
#    1578
# -> 1579         result = self.execute(*args)
#    1580         columns = result.keys()
#    1581
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1422     def execute(self, *args, **kwargs):
#    1423         """Simple passthrough to SQLAlchemy connectable"""
# -> 1424         return self.connectable.execution_options().execute(*args, **kwargs)
#    1425
#    1426     def read_table(
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    3106         """
#    3107         connection = self.connect(close_with_result=True)
# -> 3108         return connection.execute(statement, *multiparams, **params)
#    3109
#    3110     @util.deprecated_20(
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1246             )
#    1247
# -> 1248             return self._exec_driver_sql(
#    1249                 statement,
#    1250                 multiparams,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1545
#    1546         dialect = self.dialect
# -> 1547         ret = self._execute_context(
#    1548             dialect,
#    1549             dialect.execution_ctx_cls._init_statement,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1812
#    1813         except BaseException as e:
# -> 1814             self._handle_dbapi_exception(
#    1815                 e, statement, parameters, cursor, context
#    1816             )
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1997                 )
#    1998             else:
# -> 1999                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    2000
#    2001         finally:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1769                             break
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#    1773                     )
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     144             pass
#     145
# --> 146         query = self.mogrify(query, args)
#     147
#     148         result = self._query(query)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymysql\cursors.py in mogrify(self, query, args)
#     123
#     124         if args is not None:
# --> 125             query = query % self._escape_args(args, conn)
#     126
#     127         return query
#
# ValueError: unsupported format character 'A' (0x41) at index 45

# %%
# Get the 10 longest films.
length_query = "SELECT * FROM sakila.film ORDER BY `length` DESC LIMIT 10;"
Long_films = pd.read_sql_query(length_query, engine_sakila)
Long_films
# Out:
#    film_id               title  \
# 0      817  SOLDIERS EVOLUTION
# 1      872   SWEET BROTHERHOOD
# 2      141       CHICAGO NORTH
# 3      991        WORST BANGER
# 4      349         GANGS PRIDE
# 5      212      DARN FORRESTER
# 6      426           HOME PITY
# 7      609       MUSCLE BRIGHT
# 8      182      CONTROL ANTHEM
# 9      690        POND SEATTLE
#
#                                          description  release_year  \
# 0  A Lacklusture Panorama of a A Shark And a Pion...          2006
# 1  A Unbelieveable Epistle of a Sumo Wrestler And...          2006
# 2  A Fateful Yarn of a Mad Cow And a Waitress who...          2006
# 3  A Thrilling Drama of a Madman And a Dentist wh...          2006
# 4  A Taut Character Study of a Woman And a A Shar...          2006
# 5  A Fateful Story of a A Shark And a Explorer wh...          2006
# 6  A Touching Panorama of a Man And a Secret Agen...          2006
# 7  A Stunning Panorama of a Sumo Wrestler And a H...          2006
# 8  A Fateful Documentary of a Robot And a Student...          2006
# 9  A Stunning Drama of a Teacher And a Boat who m...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                7         4.99     185
# 1            1                 None                3         2.99     185
# 2            1                 None                6         4.99     185
# 3            1                 None                4         2.99     185
# 4            1                 None                4         2.99     185
# 5            1                 None                7         4.99     185
# 6            1                 None                7         4.99     185
# 7            1                 None                7         2.99     185
# 8            1                 None                7         4.99     185
# 9            1                 None                7         2.99     185
#
#    replacement_cost rating                                   special_features  \
# 0             27.99      R  Trailers,Commentaries,Deleted Scenes,Behind th...
# 1             27.99      R                                     Deleted Scenes
# 2             11.99  PG-13                   Deleted Scenes,Behind the Scenes
# 3             26.99     PG                   Deleted Scenes,Behind the Scenes
# 4             27.99  PG-13                                  Behind the Scenes
# 5             14.99      G                                     Deleted Scenes
# 6             15.99      R            Trailers,Commentaries,Behind the Scenes
# 7             23.99      G                                     Deleted Scenes
# 8              9.99      G                                       Commentaries
# 9             25.99  PG-13            Trailers,Commentaries,Behind the Scenes
#
#           last_update
# 0 2006-02-15 05:03:42
# 1 2006-02-15 05:03:42
# 2 2006-02-15 05:03:42
# 3 2006-02-15 05:03:42
# 4 2006-02-15 05:03:42
# 5 2006-02-15 05:03:42
# 6 2006-02-15 05:03:42
# 7 2006-02-15 05:03:42
# 8 2006-02-15 05:03:42
# 9 2006-02-15 05:03:42

# %%
# How many films include Behind the Scenes content?
BTS_query = '''SELECT COUNT(*) FROM sakila.film WHERE film.special_features LIKE "Behind the Scenes";'''
BTS_films = pd.read_sql_query(BTS_query,engine_sakila)
BTS_films.head()
# Out:
#    COUNT(*)
# 0        70

# %%
# Which kind of movies (rating) have a mean duration of more than two hours?
rating_length_query = "SELECT film.rating, round(AVG(film.`length`),2) AS 'Average duration' FROM sakila.film GROUP BY rating;"
long_movie_types = pd.read_sql_query(rating_length_query, engine_sakila) 
long_movie_types.head()
# Out:
#   rating  Average duration
# 0     PG            112.01
# 1      G            111.05
# 2  NC-17            113.23
# 3  PG-13            120.44
# 4      R            118.66

# %%
# Rank films by length (filter out the rows that have nulls or 0s in length column). In your output, only select the columns title, length, and the rank.
rank_query = "SELECT film.title, film.`length`, RANK() OVER(ORDER BY film.`length` DESC) AS 'rank' FROM sakila.film WHERE film.`length` IS NOT null OR film.`length` <> 0;"
rank_length = pd.read_sql_query(rank_query, engine_sakila)
rank_length
# Out:
#                    title  length  rank
# 0          CHICAGO NORTH     185     1
# 1         CONTROL ANTHEM     185     1
# 2         DARN FORRESTER     185     1
# 3            GANGS PRIDE     185     1
# 4              HOME PITY     185     1
# ..                   ...     ...   ...
# 995         ALIEN CENTER      46   996
# 996            IRON MOON      46   996
# 997        KWAI HOMEWARD      46   996
# 998     LABYRINTH LEAGUE      46   996
# 999  RIDGEMONT SUBMARINE      46   996
#
# [1000 rows x 3 columns]
